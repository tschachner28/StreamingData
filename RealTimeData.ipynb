# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps = []
raw_sigs = []
time_start = time.time()

while True:
    now = time.time()
    #raw_sig = sin(2 * np.pi * 3 * i) + sin(2 * np.pi * 0.5 * i)
    #raw_sig = sin(now - time_start)
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps.append(now - time_start)
    raw_sigs.append(raw_sig)
    i += period
        
    ax.plot(timestamps, raw_sigs, color='b')
    fig.canvas.draw()
    time.sleep(0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c822f25cf13e> in <module>
#      27
#      28     ax.plot(timestamps, raw_sigs, color='b')
# ---> 29     fig.canvas.draw()
#      30     time.sleep(0.1)
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     151             super().draw()
#     152         finally:
# --> 153             self.manager.refresh_all()  # Swap the frames.
#     154
#     155     def draw_idle(self):
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in refresh_all(self)
#     442     def refresh_all(self):
#     443         if self.web_sockets:
# --> 444             diff = self.canvas.get_diff_image()
#     445             if diff is not None:
#     446                 for s in self.web_sockets:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in get_diff_image(self)
#     199             buff = _png.write_png(
#     200                 output.view(dtype=np.uint8).reshape(output.shape + (4,)),
# --> 201                 None, compression=6, filter=_png.PNG_FILTER_NONE)
#     202
#     203             # Swap the renderer frames
#
# KeyboardInterrupt:

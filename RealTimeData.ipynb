# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps = []
raw_sigs = []
time_start = time.time()

while True:
    now = time.time()
    #raw_sig = sin(2 * np.pi * 3 * i) + sin(2 * np.pi * 0.5 * i)
    #raw_sig = sin(now - time_start)
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps.append(now - time_start)
    raw_sigs.append(raw_sig)
    i += period
        
    ax.plot(timestamps, raw_sigs, color='b')
    fig.canvas.draw()
    time.sleep(0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c822f25cf13e> in <module>
#      27
#      28     ax.plot(timestamps, raw_sigs, color='b')
# ---> 29     fig.canvas.draw()
#      30     time.sleep(0.1)
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     149         self._png_is_old = True
#     150         try:
# --> 151             super().draw()
#     152         finally:
#     153             self.manager.refresh_all()  # Swap the frames.
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/lines.py in draw(self, renderer)
#     800
#     801                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 802                 renderer.draw_path(gc, tpath, affine.frozen())
#     803                 gc.restore()
#     804
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     150         else:
#     151             try:
# --> 152                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     153             except OverflowError:
#     154                 raise OverflowError("Exceeded cell block limit (set "
#
# KeyboardInterrupt:

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = fig.add_subplot(112)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps_left_1 = []
raw_sigs_left_1 = []
timestamps_right_1 = []
raw_sigs_right_1 = []
time_start = time.time()

while True:
    now = time.time()
    
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    time.sleep(0.1)
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    time.sleep(0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-3dc619182fdd> in <module>
#       7 fig = plt.figure()
#       8 ax1 = fig.add_subplot(111)
# ----> 9 ax2 = fig.add_subplot(112)
#      10 fig.show()
#      11
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      64                 if num < 1 or num > rows*cols:
#      65                     raise ValueError(
# ---> 66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#      68                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 1, not 2

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps_left_1 = []
raw_sigs_left_1 = []
timestamps_right_1 = []
raw_sigs_right_1 = []
time_start = time.time()

while True:
    now = time.time()
    
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    time.sleep(0.1)
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    time.sleep(0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-67428f727bd3> in <module>
#      29     i += period
#      30     ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
# ---> 31     fig.canvas.draw()
#      32     time.sleep(0.1)
#      33
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     149         self._png_is_old = True
#     150         try:
# --> 151             super().draw()
#     152         finally:
#     153             self.manager.refresh_all()  # Swap the frames.
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1237         # the actual bbox
#    1238
# -> 1239         self._update_label_position(renderer)
#    1240
#    1241         self.label.draw(renderer)
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2030                 # use axes if spine doesn't exist
#    2031                 spinebbox = self.axes.bbox
# -> 2032             bbox = mtransforms.Bbox.union(bboxes + [spinebbox])
#    2033             bottom = bbox.y0
#    2034
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/transforms.py in union(bboxes)
#     703             x0 = np.min([bbox.xmin for bbox in bboxes])
#     704             x1 = np.max([bbox.xmax for bbox in bboxes])
# --> 705             y0 = np.min([bbox.ymin for bbox in bboxes])
#     706             y1 = np.max([bbox.ymax for bbox in bboxes])
#     707         return Bbox([[x0, y0], [x1, y1]])
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/transforms.py in <listcomp>(.0)
#     703             x0 = np.min([bbox.xmin for bbox in bboxes])
#     704             x1 = np.max([bbox.xmax for bbox in bboxes])
# --> 705             y0 = np.min([bbox.ymin for bbox in bboxes])
#     706             y1 = np.max([bbox.ymax for bbox in bboxes])
#     707         return Bbox([[x0, y0], [x1, y1]])
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/transforms.py in ymin(self)
#     352     def ymin(self):
#     353         """The bottom edge of the bounding box."""
# --> 354         return np.min(self.get_points()[:, 1])
#     355
#     356     @property
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/opt/miniconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2791     """
#    2792     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2793                           keepdims=keepdims, initial=initial, where=where)
#    2794
#    2795
#
# ~/opt/miniconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
# ---> 90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      91
#      92
#
# KeyboardInterrupt:

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps_left_1 = []
raw_sigs_left_1 = []
timestamps_right_1 = []
raw_sigs_right_1 = []
time_start = time.time()

while True:
    now = time.time()
    
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    time.sleep(0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7092debb197e> in <module>
#      29     i += period
#      30     ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
# ---> 31     fig.canvas.draw()
#      32
#      33     # Right Arm: Phase Shift
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     149         self._png_is_old = True
#     150         try:
# --> 151             super().draw()
#     152         finally:
#     153             self.manager.refresh_all()  # Swap the frames.
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/lines.py in draw(self, renderer)
#     800
#     801                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 802                 renderer.draw_path(gc, tpath, affine.frozen())
#     803                 gc.restore()
#     804
#
# ~/opt/miniconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     150         else:
#     151             try:
# --> 152                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     153             except OverflowError:
#     154                 raise OverflowError("Exceeded cell block limit (set "
#
# KeyboardInterrupt:

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps_left_1 = []
raw_sigs_left_1 = []
timestamps_right_1 = []
raw_sigs_right_1 = []
time_start = time.time()

#while True:
while (now - time_start < 10):
    now = time.time()
    
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    time.sleep(0.1)

with open('torque1', 'a') as f:
    # Write left and right torque for dataset 1. Format: left torque, right torque, timestamp
    for i in range(0,len(timestamps_left_1)):
        f.write([raw_sigs_left_1[i], raw_sigs_right_1[i], timestamps_left_1[i]])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-da9556c5f084> in <module>
#      44     # Write left and right torque for dataset 1. Format: left torque, right torque, timestamp
#      45     for i in range(0,len(timestamps_left_1)):
# ---> 46         f.write([raw_sigs_left_1[i], raw_sigs_right_1[i], timestamps_left_1[i]])
#      47
#
# TypeError: write() argument must be str, not list

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps_left_1 = []
raw_sigs_left_1 = []
timestamps_right_1 = []
raw_sigs_right_1 = []
time_start = time.time()

#while True:
while (now - time_start < 10):
    now = time.time()
    
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    time.sleep(0.1)

with open('torque1.csv', 'w') as f:
    # Write left and right torque for dataset 1. Format: left torque, right torque, timestamp
    for i in range(0,len(timestamps_left_1)):
        print([raw_sigs_left_1[i], raw_sigs_right_1[i], timestamps_left_1[i]], file=f)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps_left_1 = []
raw_sigs_left_1 = []
timestamps_right_1 = []
raw_sigs_right_1 = []
time_start = time.time()

#while True:
while (now - time_start < 10):
    now = time.time()
    
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    time.sleep(0.01)

with open('torque1.csv', 'w') as f:
    # Write left and right torque for dataset 1. Format: left torque, right torque, timestamp
    for i in range(0,len(timestamps_left_1)):
        print([raw_sigs_left_1[i], raw_sigs_right_1[i], timestamps_left_1[i]], file=f)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps_left_1 = []
raw_sigs_left_1 = []
timestamps_right_1 = []
raw_sigs_right_1 = []
timestamps_left_2 = []
raw_sigs_left_2 = []
timestamps_right_2 = []
raw_sigs_right_2 = []
time_start = time.time()

#while True:
while (now - time_start < 10):
    now = time.time()
    
    # Dataset 1
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    
    # Dataset 2
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    
    time.sleep(0.01)
    
    

with open('torque_set_1.csv', 'w') as f:
    # Write left and right torque for dataset 1. Format: left torque, right torque, timestamp
    for i in range(0,len(timestamps_left_1)):
        print([raw_sigs_left_1[i], raw_sigs_right_1[i], timestamps_left_1[i]], file=f)

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps_left_1 = []
raw_sigs_left_1 = []
timestamps_right_1 = []
raw_sigs_right_1 = []
timestamps_left_2 = []
raw_sigs_left_2 = []
timestamps_right_2 = []
raw_sigs_right_2 = []
time_start = time.time()

#while True:
while (now - time_start < 10):
    now = time.time()
    
    # Dataset 1
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    
    # Dataset 2
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    fig.canvas.draw()
    
    time.sleep(0.01)
    
    

with open('torque_set_1.csv', 'w') as f:
    # Write left and right torque for dataset 1. Format: left torque, right torque, timestamp
    for i in range(0,len(timestamps_left_1)):
        print([raw_sigs_left_1[i], raw_sigs_right_1[i], timestamps_left_1[i]], file=f)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
#ax3 = fig.add_subplot(337)
#ax4 = fig.add_subplot(338)
fig.show()

#period = 1.0 / 1000
#i = 0

timestamps_left_1 = []
raw_sigs_left_1 = []
timestamps_right_1 = []
raw_sigs_right_1 = []
"""
timestamps_left_2 = []
raw_sigs_left_2 = []
timestamps_right_2 = []
raw_sigs_right_2 = []
"""
time_start = time.time()

# Generate and graph data in real time
while (time.time() - time_start < 15):
    now = time.time()
    
    # Dataset 1
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start))
    timestamps_left_1.append(now - time_start)
    raw_sigs_left_1.append(raw_sig)
    #i += period
    ax1.plot(timestamps_left_1, raw_sigs_left_1, color='b')
    ax1.set_title('Left Arm (Dataset 1)')
    ax1.set_xlabel('Time')
    ax1.set_ylabel('Torque')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start) + np.pi) # phase shift from left arm
    timestamps_right_1.append(now - time_start)
    raw_sigs_right_1.append(raw_sig)
    #i += period
    ax2.plot(timestamps_right_1, raw_sigs_right_1, color='b')
    ax2.set_title('Right Arm (Dataset 1)')
    ax2.set_xlabel('Time')
    ax2.set_ylabel('Torque')
    fig.canvas.draw()
    """
    # Dataset 2
    # Left Arm
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start)**2)
    timestamps_left_2.append(now - time_start)
    raw_sigs_left_2.append(raw_sig)
    #i += period
    ax3.plot(timestamps_left_2, raw_sigs_left_2, color='g')
    ax3.set_title('Left Arm (Dataset 2)')
    ax3.set_xlabel('Time')
    ax3.set_ylabel('Torque')
    fig.canvas.draw()
    
    # Right Arm: Phase Shift
    raw_sig = 2 * sin(2 * np.pi * 1000 * (now - time_start)**2 + np.pi/2) # phase shift from left arm
    timestamps_right_2.append(now - time_start)
    raw_sigs_right_2.append(raw_sig)
    #i += period
    ax4.plot(timestamps_right_2, raw_sigs_right_2, color='g')
    ax4.set_title('Right Arm (Dataset 2)')
    ax4.set_xlabel('Time')
    ax4.set_ylabel('Torque')
    fig.canvas.draw()
    """
    
# Write data to files
with open('torque_set_1.csv', 'w') as f:
    # Write left and right torque for dataset 1. Format: left torque, right torque, timestamp
    for i in range(0,len(timestamps_left_1)):
        print([raw_sigs_left_1[i], raw_sigs_right_1[i], timestamps_left_1[i]], file=f)
        
"""        
with open('torque_set_2.csv', 'w') as f:
    # Write left and right torque for dataset 2. Format: left torque, right torque, timestamp
    for i in range(0,len(timestamps_left_2)):
        print([raw_sigs_left_2[i], raw_sigs_right_2[i], timestamps_left_2[i]], file=f)
"""
# Out:
# <img src="data:image/png;base64,..." width="640">
# "        \nwith open('torque_set_2.csv', 'w') as f:\n    # Write left and right torque for dataset 2. Format: left torque, right torque, timestamp\n    for i in range(0,len(timestamps_left_2)):\n        print([raw_sigs_left_2[i], raw_sigs_right_2[i], timestamps_left_2[i]], file=f)\n"

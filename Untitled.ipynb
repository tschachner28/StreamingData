# %% [markdown]
# ## Plot
# $$
# f(x) = \frac{1}{x}
# $$

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-100,100,100)
plt.plot(x, np.sin(x)/x)
plt.show()

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
i = 0
x, y = [], []

while True:
    x.append(i)
    y.append(np.sin(i))
    
    ax.plot(x, y, color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right=i+50)
    
    time.sleep(0.1)
    i += 1
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-28633733b484> in <module>
#      16     ax.set_xlim(left=max(0, i-50), right=i+50)
#      17
# ---> 18     time.sleep(0.1)
#      19     i += 1
#
# NameError: name 'time' is not defined
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib notebook
import time
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
In [ ]:
i = 0
x, y = [], []

while True:
    x.append(i)
    y.append(np.sin(i))
    
    ax.plot(x, y, color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right=i+50)
    
    time.sleep(0.1)
    i += 1
# Out:
#   File "<ipython-input-3-0623e9b7e2d3>", line 9
#     In [ ]:
#          ^
# SyntaxError: invalid syntax

# %%
# %matplotlib notebook
import time
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0
x, y = [], []

while True:
    x.append(i)
    y.append(np.sin(i))
    
    ax.plot(x, y, color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right=i+50)
    
    time.sleep(0.1)
    i += 1
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
from fakeStreaming import *
jupyter_test(1,2)

# %%
from fakeStreaming import *
ans = jupyter_test(1,2)
print(ans)

# %%
# %matplotlib notebook
import time
import numpy as np
import matplotlib.pyplot as plt
from fakeStreaming import *

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0
timestamps, raw_sigs = jupyter_test()
x = []
y = []

while True:
    x.append(timestamps[i])
    y.append(raw_sigs(i))
    
    ax.plot(x, y, color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right=i+50)
    
    time.sleep(0.1)
    i += 1

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt
from fakeStreaming import *

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0

while True:
    period = 1.0 / ni_fs
    i = 0
    timestamps = []
    raw_sigs = []
    time_start = time.time()
    while time.time()-time_start < duration:
        #print(i)
        now = time.time()
        raw_sig = sin(2 * np.pi * 3 * i) + sin(2 * np.pi * 0.5 * i)
        timestamps.append(now - time_start)
        raw_sigs.append(raw_sig)
        i += period
        
        ax.plot(timestamps, raw_sigs, color='b')
        fig.canvas.draw()
        ax.set_xlim(left=max(0, i-50), right=i+50)
        time.sleep(0.1)

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt
from fakeStreaming import *

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0

while True:
    period = 1.0 / 1000
    i = 0
    timestamps = []
    raw_sigs = []
    time_start = time.time()
    while time.time()-time_start < 15:
        #print(i)
        now = time.time()
        raw_sig = sin(2 * np.pi * 3 * i) + sin(2 * np.pi * 0.5 * i)
        timestamps.append(now - time_start)
        raw_sigs.append(raw_sig)
        i += period
        
        ax.plot(timestamps, raw_sigs, color='b')
        fig.canvas.draw()
        ax.set_xlim(left=max(0, i-50), right=i+50)
        time.sleep(0.1)

# %%
# %matplotlib notebook
import time
from math import sin
import numpy as np
import matplotlib.pyplot as plt
from fakeStreaming import *

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0

period = 1.0 / 1000
i = 0
timestamps = []
raw_sigs = []
time_start = time.time()

#while time.time()-time_start < 15:
while True:
    now = time.time()
    raw_sig = sin(2 * np.pi * 3 * i) + sin(2 * np.pi * 0.5 * i)
    timestamps.append(now - time_start)
    raw_sigs.append(raw_sig)
    i += period
        
    ax.plot(timestamps, raw_sigs, color='b')
    fig.canvas.draw()
    ax.set_xlim(left=max(0, i-50), right=i+50)
    time.sleep(0.1)

# %%
# %matplotlib notebook
import time
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0
x, y = [], []

while True:
    x.append(i)
    y.append(np.sin(i))
    
    ax.plot(x, y, color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right=i+50)
    
    time.sleep(0.1)
    i += 1

# %% [markdown]
# %matplotlib notebook
# import time
# import numpy as np
# import matplotlib.pyplot as plt
#
# fig = plt.figure()
# ax = fig.add_subplot(111)
# fig.show()
#
# i = 0
# x, y = [], []
#
# while True:
#     x.append(i)
#     y.append(np.sin(i))
#
#     ax.plot(x, y, color='b')
#
#     fig.canvas.draw()
#
#     ax.set_xlim(left=max(0, i-50), right=i+50)
#
#     time.sleep(0.1)
#     i += 1

# %%
# %matplotlib notebook
import time
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0
x, y = [], []

while True:
    x.append(i)
    y.append(np.sin(i))
    
    ax.plot(x, y, color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right=i+50)
    
    time.sleep(0.1)
    i += 1

# %%
# %matplotlib notebook
import time
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

i = 0
x, y = [], []

while True:
    x.append(i)
    y.append(np.sin(i))
    
    ax.plot(x, y, color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right=i+50)
    
    time.sleep(0.1)
    i += 1
